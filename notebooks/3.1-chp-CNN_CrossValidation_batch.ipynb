# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from bbox_plotter import midpt_to_corners #______________
from torchvision.ops import complete_box_iou_loss
import numpy as np
import csv
import os
from sklearn.model_selection import KFold

# %%
class ZebrafishDataset(Dataset):
    def __init__(self, images_path, labels_path, transform=None):
        self.images = np.load(images_path)
        self.labels = np.load(labels_path)
        self.transform = transform
        
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        image = self.images[idx]
        label = self.labels[idx]
        if self.transform:
            image = self.transform(image)
        
        return torch.tensor(image, dtype=torch.float32), torch.tensor(label, dtype=torch.float32)

# %%
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(in_features=128 * 26 * 26, out_features=128)
        self.fc2 = nn.Linear(in_features=128, out_features=64)
        self.fc3 = nn.Linear(in_features=64, out_features=4)
        
        
    def forward(self, x):
        x = self.pool1(torch.relu(self.conv1(x)))
        x = self.pool2(torch.relu(self.conv2(x)))
        x = self.pool3(torch.relu(self.conv3(x)))
                
        x = self.flatten(x)
        
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.sigmoid(self.fc3(x))
        
        return x

# %%
def reset_weights(model):
    for layer in model.children():
        if hasattr(layer, 'reset_parameters'):
            layer.reset_parameters()

# %%
class CompleteBoxLoss(nn.Module):
    def __init__(self):
        super(CompleteBoxLoss, self).__init__()

    def forward(self, pred_boxes, true_boxes, reduction):
        ciou = complete_box_iou_loss(pred_boxes, true_boxes, reduction)
        
        return ciou

# %%
# ____________ 

def Initialize_writer(file_path,columns = ['epoch','loss','val_loss']):
    os.makedirs(os.path.dirname(file_path), exist_ok=True)
    with open(file_path, mode='w', newline="") as file:
        writer = csv.writer(file)
        writer.writerow(columns)

# %%
images_path = "D:\Praharsha\Code\CAMZ\data\interim\X_labelled_data.npy"
labels_path = "D:\Praharsha\Code\CAMZ\data\interim\y_labelled_data.npy"

transform = transforms.ToTensor()
dataset = ZebrafishDataset(images_path, labels_path, transform=transform)

# %%
k_folds = 5
num_epochs = 100
loss_function = CompleteBoxLoss()
batch_size = 32

# %%
kfold = KFold(n_splits=k_folds, shuffle=True)

fold_results = []

for fold, (train_ids, test_ids) in enumerate(kfold.split(dataset)):
    print(f"Fold: {fold+1}")
    print('-----------------------------------------------------------------------------------------')
    
    train_subsampler = torch.utils.data.SubsetRandomSampler(train_ids)
    test_subsampler = torch.utils.data.SubsetRandomSampler(test_ids)
    
    train_loader = DataLoader(dataset, batch_size=batch_size, sampler=train_subsampler)
    test_loader = DataLoader(dataset, batch_size=batch_size, sampler=test_subsampler)
    
    model = CNNModel()
    print("Resetting the model for upcoming training session")
    model.apply(reset_weights)
    
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    
    epoch_history_csv_path = rf"D:\Praharsha\Code\CAMZ\models\CrossValidation_history\fold_{fold+1}\epoch_history"
    batch_train_history_csv_path = rf"D:\Praharsha\Code\CAMZ\models\CrossValidation_history\fold_{fold+1}\batch_train_history" #____________
    batch_val_history_csv_path = rf"D:\Praharsha\Code\CAMZ\models\CrossValidation_history\fold_{fold+1}\batch_val_history" #______________

    Initialize_writer(epoch_history_csv_path)
    Initialize_writer(batch_train_history_csv_path,columns=['epoch', 'batch', 'loss'])  #_____________
    Initialize_writer(batch_val_history_csv_path, columns=['epoch','batch','loss']) # _____________
    
    best_val_ciou_loss = float('inf')
    
    for epoch in range(num_epochs):
        #Training Pipeline
        model.train()
        ciou_total_batch_loss = 0.0

        ciou_loss_per_batch_train_history = []  #___________
        batch_num = 1  #____________
         
        for inputs, labels in train_loader:
            
            optimizer.zero_grad()
            
            norm_labels = midpt_to_corners(labels, image_width=720, image_height=720)
            outputs = midpt_to_corners(model(inputs), image_width=720, image_height=720)
                     
            
            ciou_loss_per_batch = loss_function(outputs, norm_labels, 'mean')
            
            ciou_loss_per_batch.backward()
            
            optimizer.step()
            
            ciou_loss_per_batch_train_history.append([epoch, batch_num, ciou_loss_per_batch.item()])  #____________

            ciou_total_batch_loss += ciou_loss_per_batch.item()

            batch_num += 1  #_______________
        
        ciou_loss_per_epoch = ciou_total_batch_loss / len(train_loader)
        
        print(end='\n')
        print(f"Fold [{fold+1}/{k_folds}], Epoch [{epoch+1}/{num_epochs}], CIoU: {ciou_loss_per_epoch:.4f}", end=" --- ")
        
        # Validation Pipeline
        model.eval()
        ciou_total_batch_loss = 0.0
        
        ciou_loss_per_batch_val_history = []  #___________
        batch_num = 1  #____________

        with torch.no_grad():
            for inputs, labels in test_loader:
                norm_labels = midpt_to_corners(labels, image_width=720, image_height=720)
                outputs = midpt_to_corners(model(inputs), image_width=720, image_height=720)
                
                ciou_loss_per_batch = loss_function(outputs, norm_labels, 'mean')

                ciou_loss_per_batch_val_history.append([epoch, batch_num, ciou_loss_per_batch.item()])  #______________

                ciou_total_batch_loss += ciou_loss_per_batch.item()

                batch_num += 1  #_____________
        
        val_ciou_loss = ciou_total_batch_loss / len(test_loader)
        print(f"Validation for Epoch [{epoch+1}/{num_epochs}], CIoU: {val_ciou_loss}")
        
        # Save model for this epoch if it's the best so far
        if val_ciou_loss < best_val_ciou_loss:
            best_val_ciou_loss = val_ciou_loss
            torch.save(model.state_dict(), f'D:\Praharsha\Code\CAMZ\models\model_fold_{fold + 1}.pth')
            print(f"Saving best model for Fold {fold + 1} at Epoch {epoch + 1}")


        with open(epoch_history_csv_path, mode='a', newline="") as file:
            loss_writer = csv.writer(file)
            loss_writer.writerow([epoch+1, ciou_loss_per_epoch, val_ciou_loss])

        #_______________
        with open(batch_train_history_csv_path,'a',newline="") as file:
            loss_writer = csv.writer(file)
            loss_writer.writerows(ciou_loss_per_batch_train_history)

        #_______________
        with open(batch_val_history_csv_path, 'a', newline="") as file:
            loss_writer = csv.writer(file)
            loss_writer.writerows(ciou_loss_per_batch_val_history)

    print(f"Best Validation CIoU for Fold {fold + 1}: {best_val_ciou_loss:.4f}")


    fold_results.append((fold + 1, best_val_ciou_loss))

# Print all results at the end
print("\nK-Fold Cross-Validation Results:")
print("Fold\tBest Validation CIoU Loss")
for fold, best_loss in fold_results:
    print(f"{fold}\t{best_loss:.4f}")

# Print the average CIoU loss across folds
avg_val_ciou_loss = sum(loss for _, loss in fold_results) / k_folds
print(f"\nAverage Validation CIoU Loss Across All Folds: {avg_val_ciou_loss:.4f}")
# Out:
# Fold: 1
# -----------------------------------------------------------------------------------------
# Resetting the model for upcoming training session
# C:\Users\USER\AppData\Local\Temp\ipykernel_6656\2341323471.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(image, dtype=torch.float32), torch.tensor(label, dtype=torch.float32)
# Fold [1/5], Epoch [1/100], CIoU: 1.0320 --- Validation for Epoch [1/100], CIoU: 1.027036468187968
# Saving best model for Fold 1 at Epoch 1
#
# Fold [1/5], Epoch [2/100], CIoU: 1.0242 --- Validation for Epoch [2/100], CIoU: 1.0153332869211833
# Saving best model for Fold 1 at Epoch 2
#
# Fold [1/5], Epoch [3/100], CIoU: 0.9667 --- Validation for Epoch [3/100], CIoU: 0.8301832675933838
# Saving best model for Fold 1 at Epoch 3
#
# Fold [1/5], Epoch [4/100], CIoU: 0.6856 --- Validation for Epoch [4/100], CIoU: 0.5576498925685882
# Saving best model for Fold 1 at Epoch 4
#
# Fold [1/5], Epoch [5/100], CIoU: 0.5486 --- Validation for Epoch [5/100], CIoU: 0.4962119281291962
# Saving best model for Fold 1 at Epoch 5
#
# Fold [1/5], Epoch [6/100], CIoU: 0.4967 --- Validation for Epoch [6/100], CIoU: 0.4350904484589895
# Saving best model for Fold 1 at Epoch 6
#
# Fold [1/5], Epoch [7/100], CIoU: 0.4643 --- Validation for Epoch [7/100], CIoU: 0.43045100768407185
# Saving best model for Fold 1 at Epoch 7
#
# Fold [1/5], Epoch [8/100], CIoU: 0.4356 --- Validation for Epoch [8/100], CIoU: 0.46832944949467975
#
# Fold [1/5], Epoch [9/100], CIoU: 0.4187 --- Validation for Epoch [9/100], CIoU: 0.4659459312756856
#
# Fold [1/5], Epoch [10/100], CIoU: 0.4196 --- Validation for Epoch [10/100], CIoU: 0.4264479875564575
# Saving best model for Fold 1 at Epoch 10
#
# Fold [1/5], Epoch [11/100], CIoU: 0.3889 --- Validation for Epoch [11/100], CIoU: 0.3721278448899587
# Saving best model for Fold 1 at Epoch 11
#
# Fold [1/5], Epoch [12/100], CIoU: 0.3958 --- Validation for Epoch [12/100], CIoU: 0.4220201810201009
#
# Fold [1/5], Epoch [13/100], CIoU: 0.3720 --- Validation for Epoch [13/100], CIoU: 0.3989292542139689
#
# Fold [1/5], Epoch [14/100], CIoU: 0.3596 --- Validation for Epoch [14/100], CIoU: 0.3943524082501729
#
# Fold [1/5], Epoch [15/100], CIoU: 0.3466 --- Validation for Epoch [15/100], CIoU: 0.38531151016553244
#
# Fold [1/5], Epoch [16/100], CIoU: 0.3389 --- Validation for Epoch [16/100], CIoU: 0.3687695602575938
# Saving best model for Fold 1 at Epoch 16
#
# Fold [1/5], Epoch [17/100], CIoU: 0.3395 --- Validation for Epoch [17/100], CIoU: 0.41765064001083374
#
# Fold [1/5], Epoch [18/100], CIoU: 0.3303 --- Validation for Epoch [18/100], CIoU: 0.34677477478981017
# Saving best model for Fold 1 at Epoch 18
#
# Fold [1/5], Epoch [19/100], CIoU: 0.3095 --- Validation for Epoch [19/100], CIoU: 0.3562223553657532
#
# Fold [1/5], Epoch [20/100], CIoU: 0.3115 --- Validation for Epoch [20/100], CIoU: 0.3304961025714874
# Saving best model for Fold 1 at Epoch 20
#
# Fold [1/5], Epoch [21/100], CIoU: 0.3013 --- Validation for Epoch [21/100], CIoU: 0.34401370882987975
#
# Fold [1/5], Epoch [22/100], CIoU: 0.3060 --- Validation for Epoch [22/100], CIoU: 0.33248443007469175
#
# Fold [1/5], Epoch [23/100], CIoU: 0.2950 --- Validation for Epoch [23/100], CIoU: 0.36761690576871237
#
# Fold [1/5], Epoch [24/100], CIoU: 0.2831 --- Validation for Epoch [24/100], CIoU: 0.3665464500586192
#
# Fold [1/5], Epoch [25/100], CIoU: 0.2856 --- Validation for Epoch [25/100], CIoU: 0.39510127902030945
#
# Fold [1/5], Epoch [26/100], CIoU: 0.2938 --- Validation for Epoch [26/100], CIoU: 0.31474941273530327
# Saving best model for Fold 1 at Epoch 26
#
# Fold [1/5], Epoch [27/100], CIoU: 0.2763 --- Validation for Epoch [27/100], CIoU: 0.3213293790817261
#
# Fold [1/5], Epoch [28/100], CIoU: 0.2921 --- Validation for Epoch [28/100], CIoU: 0.5848216970761617
#
# Fold [1/5], Epoch [29/100], CIoU: 0.3182 --- Validation for Epoch [29/100], CIoU: 0.3574637512365977
#
# Fold [1/5], Epoch [30/100], CIoU: 0.2742 --- Validation for Epoch [30/100], CIoU: 0.33323350350062053
#
# Fold [1/5], Epoch [31/100], CIoU: 0.2711 --- Validation for Epoch [31/100], CIoU: 0.2986906409263611
# Saving best model for Fold 1 at Epoch 31
#
# Fold [1/5], Epoch [32/100], CIoU: 0.2564 --- Validation for Epoch [32/100], CIoU: 0.31477756102879845
#
# Fold [1/5], Epoch [33/100], CIoU: 0.2524 --- Validation for Epoch [33/100], CIoU: 0.30239103436470033
#
# Fold [1/5], Epoch [34/100], CIoU: 0.2491 --- Validation for Epoch [34/100], CIoU: 0.30164053042729694
#
# Fold [1/5], Epoch [35/100], CIoU: 0.2477 --- Validation for Epoch [35/100], CIoU: 0.3018127024173737
#
# Fold [1/5], Epoch [36/100], CIoU: 0.2588 --- Validation for Epoch [36/100], CIoU: 0.33478530049324035
#
# Fold [1/5], Epoch [37/100], CIoU: 0.2554 --- Validation for Epoch [37/100], CIoU: 0.312260768810908
#
# Fold [1/5], Epoch [38/100], CIoU: 0.2440 --- Validation for Epoch [38/100], CIoU: 0.3172539373238881
#
# Fold [1/5], Epoch [39/100], CIoU: 0.2270 --- Validation for Epoch [39/100], CIoU: 0.30538257559140525
#
# Fold [1/5], Epoch [40/100], CIoU: 0.2285 --- Validation for Epoch [40/100], CIoU: 0.2946636954943339
# Saving best model for Fold 1 at Epoch 40
#
# Fold [1/5], Epoch [41/100], CIoU: 0.2301 --- Validation for Epoch [41/100], CIoU: 0.307753449678421
#
# Fold [1/5], Epoch [42/100], CIoU: 0.2279 --- Validation for Epoch [42/100], CIoU: 0.3158111492792765
#
# Fold [1/5], Epoch [43/100], CIoU: 0.2367 --- Validation for Epoch [43/100], CIoU: 0.31563603480656943
#
# Fold [1/5], Epoch [44/100], CIoU: 0.2154 --- Validation for Epoch [44/100], CIoU: 0.2917613784472148
# Saving best model for Fold 1 at Epoch 44
#
# Fold [1/5], Epoch [45/100], CIoU: 0.2190 --- Validation for Epoch [45/100], CIoU: 0.29579870998859403
#
# Fold [1/5], Epoch [46/100], CIoU: 0.2108 --- Validation for Epoch [46/100], CIoU: 0.3106398403644562
#
# Fold [1/5], Epoch [47/100], CIoU: 0.2061 --- Validation for Epoch [47/100], CIoU: 0.30489653746287027
#
# Fold [1/5], Epoch [48/100], CIoU: 0.2028 --- Validation for Epoch [48/100], CIoU: 0.30059175888697304
#
# Fold [1/5], Epoch [49/100], CIoU: 0.2082 --- Validation for Epoch [49/100], CIoU: 0.32601108551025393
#
# Fold [1/5], Epoch [50/100], CIoU: 0.2013 --- Validation for Epoch [50/100], CIoU: 0.3190084993839264
#
# Fold [1/5], Epoch [51/100], CIoU: 0.2122 --- Validation for Epoch [51/100], CIoU: 0.3013212343056997
#
# Fold [1/5], Epoch [52/100], CIoU: 0.1938 --- Validation for Epoch [52/100], CIoU: 0.30163064002990725
#
# Fold [1/5], Epoch [53/100], CIoU: 0.2092 --- Validation for Epoch [53/100], CIoU: 0.3059675494829814
#
# Fold [1/5], Epoch [54/100], CIoU: 0.2041 --- Validation for Epoch [54/100], CIoU: 0.3155746698379517
#
# Fold [1/5], Epoch [55/100], CIoU: 0.1954 --- Validation for Epoch [55/100], CIoU: 0.2960014174381892
#
# Fold [1/5], Epoch [56/100], CIoU: 0.1942 --- Validation for Epoch [56/100], CIoU: 0.29851407210032144
#
# Fold [1/5], Epoch [57/100], CIoU: 0.1933 --- Validation for Epoch [57/100], CIoU: 0.2981512178977331
#
# Fold [1/5], Epoch [58/100], CIoU: 0.1934 --- Validation for Epoch [58/100], CIoU: 0.3164428551991781
#
# Fold [1/5], Epoch [59/100], CIoU: 0.1853 --- Validation for Epoch [59/100], CIoU: 0.3031510243813197
#
# Fold [1/5], Epoch [60/100], CIoU: 0.1847 --- Validation for Epoch [60/100], CIoU: 0.29456440011660256
#
# Fold [1/5], Epoch [61/100], CIoU: 0.1889 --- Validation for Epoch [61/100], CIoU: 0.28947287102540337
# Saving best model for Fold 1 at Epoch 61
#
# Fold [1/5], Epoch [62/100], CIoU: 0.1759 --- Validation for Epoch [62/100], CIoU: 0.291305410861969
#
# Fold [1/5], Epoch [63/100], CIoU: 0.1822 --- Validation for Epoch [63/100], CIoU: 0.301413102944692
#
# Fold [1/5], Epoch [64/100], CIoU: 0.1810 --- Validation for Epoch [64/100], CIoU: 0.29952045281728107
#
# Fold [1/5], Epoch [65/100], CIoU: 0.1755 --- Validation for Epoch [65/100], CIoU: 0.3159192442893982
#
# Fold [1/5], Epoch [66/100], CIoU: 0.1927 --- Validation for Epoch [66/100], CIoU: 0.30255865852038066
#
# Fold [1/5], Epoch [67/100], CIoU: 0.1824 --- Validation for Epoch [67/100], CIoU: 0.32425187627474467
#
# Fold [1/5], Epoch [68/100], CIoU: 0.1917 --- Validation for Epoch [68/100], CIoU: 0.3105258146921794
#
# Fold [1/5], Epoch [69/100], CIoU: 0.1802 --- Validation for Epoch [69/100], CIoU: 0.30146681467692055
#
# Fold [1/5], Epoch [70/100], CIoU: 0.1715 --- Validation for Epoch [70/100], CIoU: 0.3086624026298523
#
# Fold [1/5], Epoch [71/100], CIoU: 0.1820 --- Validation for Epoch [71/100], CIoU: 0.32871156533559165
#
# Fold [1/5], Epoch [72/100], CIoU: 0.1673 --- Validation for Epoch [72/100], CIoU: 0.2965605427821477
#
# Fold [1/5], Epoch [73/100], CIoU: 0.1652 --- Validation for Epoch [73/100], CIoU: 0.2930697530508041
#
# Fold [1/5], Epoch [74/100], CIoU: 0.1690 --- Validation for Epoch [74/100], CIoU: 0.30875471929709114
#
# Fold [1/5], Epoch [75/100], CIoU: 0.1722 --- Validation for Epoch [75/100], CIoU: 0.31816169023513796
#
# Fold [1/5], Epoch [76/100], CIoU: 0.1638 --- Validation for Epoch [76/100], CIoU: 0.28540722529093426
# Saving best model for Fold 1 at Epoch 76
#
# Fold [1/5], Epoch [77/100], CIoU: 0.1656 --- Validation for Epoch [77/100], CIoU: 0.2904398332039515
#
# Fold [1/5], Epoch [78/100], CIoU: 0.1818 --- Validation for Epoch [78/100], CIoU: 0.3244286288817724
#
# Fold [1/5], Epoch [79/100], CIoU: 0.1759 --- Validation for Epoch [79/100], CIoU: 0.307461475332578
#
# Fold [1/5], Epoch [80/100], CIoU: 0.1671 --- Validation for Epoch [80/100], CIoU: 0.3077078819274902
#
# Fold [1/5], Epoch [81/100], CIoU: 0.1628 --- Validation for Epoch [81/100], CIoU: 0.29601353605588276
#
# Fold [1/5], Epoch [82/100], CIoU: 0.1586 --- Validation for Epoch [82/100], CIoU: 0.29380788207054137
#
# Fold [1/5], Epoch [83/100], CIoU: 0.1696 --- Validation for Epoch [83/100], CIoU: 0.3028053124745687
#
# Fold [1/5], Epoch [84/100], CIoU: 0.1652 --- Validation for Epoch [84/100], CIoU: 0.29092830419540405
#
# Fold [1/5], Epoch [85/100], CIoU: 0.1800 --- Validation for Epoch [85/100], CIoU: 0.2847799648841222
# Saving best model for Fold 1 at Epoch 85
#
# Fold [1/5], Epoch [86/100], CIoU: 0.1558 --- Validation for Epoch [86/100], CIoU: 0.3182956000169118
#
# Fold [1/5], Epoch [87/100], CIoU: 0.1667 --- Validation for Epoch [87/100], CIoU: 0.3001757860183716
#
# Fold [1/5], Epoch [88/100], CIoU: 0.1580 --- Validation for Epoch [88/100], CIoU: 0.28976272443930307
#
# Fold [1/5], Epoch [89/100], CIoU: 0.1713 --- Validation for Epoch [89/100], CIoU: 0.304540678858757
#
# Fold [1/5], Epoch [90/100], CIoU: 0.1551 --- Validation for Epoch [90/100], CIoU: 0.2872879922389984
#
# Fold [1/5], Epoch [91/100], CIoU: 0.1554 --- Validation for Epoch [91/100], CIoU: 0.29164856870969136
#
# Fold [1/5], Epoch [92/100], CIoU: 0.1601 --- Validation for Epoch [92/100], CIoU: 0.2909359137217204
#
# Fold [1/5], Epoch [93/100], CIoU: 0.1496 --- Validation for Epoch [93/100], CIoU: 0.2961978316307068
#
# Fold [1/5], Epoch [94/100], CIoU: 0.1563 --- Validation for Epoch [94/100], CIoU: 0.3216886738936106
#
# Fold [1/5], Epoch [95/100], CIoU: 0.1622 --- Validation for Epoch [95/100], CIoU: 0.3007542888323466
#
# Fold [1/5], Epoch [96/100], CIoU: 0.1607 --- Validation for Epoch [96/100], CIoU: 0.2999765694141388
#
# Fold [1/5], Epoch [97/100], CIoU: 0.1544 --- Validation for Epoch [97/100], CIoU: 0.29499215483665464
#
# Fold [1/5], Epoch [98/100], CIoU: 0.1448 --- Validation for Epoch [98/100], CIoU: 0.3162137657403946
#
# Fold [1/5], Epoch [99/100], CIoU: 0.1663 --- Validation for Epoch [99/100], CIoU: 0.3046283115943273
#
# Fold [1/5], Epoch [100/100], CIoU: 0.1579 --- Validation for Epoch [100/100], CIoU: 0.29171296854813894
# Best Validation CIoU for Fold 1: 0.2848
# Fold: 2
# -----------------------------------------------------------------------------------------
# Resetting the model for upcoming training session
#
# Fold [2/5], Epoch [1/100], CIoU: 1.0306 --- Validation for Epoch [1/100], CIoU: 1.0278171300888062
# Saving best model for Fold 2 at Epoch 1
#
# Fold [2/5], Epoch [2/100], CIoU: 1.0143 --- Validation for Epoch [2/100], CIoU: 0.9965273459752401
# Saving best model for Fold 2 at Epoch 2
#
# Fold [2/5], Epoch [3/100], CIoU: 0.9607 --- Validation for Epoch [3/100], CIoU: 0.8143888910611471
# Saving best model for Fold 2 at Epoch 3
#
# Fold [2/5], Epoch [4/100], CIoU: 0.6988 --- Validation for Epoch [4/100], CIoU: 0.5633424957593282
# Saving best model for Fold 2 at Epoch 4
#
# Fold [2/5], Epoch [5/100], CIoU: 0.5371 --- Validation for Epoch [5/100], CIoU: 0.5541892449061075
# Saving best model for Fold 2 at Epoch 5
#
# Fold [2/5], Epoch [6/100], CIoU: 0.5017 --- Validation for Epoch [6/100], CIoU: 0.5480209032694499
# Saving best model for Fold 2 at Epoch 6
#
# Fold [2/5], Epoch [7/100], CIoU: 0.4812 --- Validation for Epoch [7/100], CIoU: 0.45351781845092776
# Saving best model for Fold 2 at Epoch 7
#
# Fold [2/5], Epoch [8/100], CIoU: 0.4236 --- Validation for Epoch [8/100], CIoU: 0.43720606168111165
# Saving best model for Fold 2 at Epoch 8
#
# Fold [2/5], Epoch [9/100], CIoU: 0.4157 --- Validation for Epoch [9/100], CIoU: 0.4980460345745087
#
# Fold [2/5], Epoch [10/100], CIoU: 0.3986 --- Validation for Epoch [10/100], CIoU: 0.4491005341211955
#
# Fold [2/5], Epoch [11/100], CIoU: 0.3929 --- Validation for Epoch [11/100], CIoU: 0.4366434653600057
# Saving best model for Fold 2 at Epoch 11
#
# Fold [2/5], Epoch [12/100], CIoU: 0.3931 --- Validation for Epoch [12/100], CIoU: 0.3995678544044495
# Saving best model for Fold 2 at Epoch 12
#
# Fold [2/5], Epoch [13/100], CIoU: 0.3576 --- Validation for Epoch [13/100], CIoU: 0.36131912569204966
# Saving best model for Fold 2 at Epoch 13
#
# Fold [2/5], Epoch [14/100], CIoU: 0.3636 --- Validation for Epoch [14/100], CIoU: 0.375412380695343
#
# Fold [2/5], Epoch [15/100], CIoU: 0.3509 --- Validation for Epoch [15/100], CIoU: 0.40972601175308226
#
# Fold [2/5], Epoch [16/100], CIoU: 0.3395 --- Validation for Epoch [16/100], CIoU: 0.3838805019855499
#
# Fold [2/5], Epoch [17/100], CIoU: 0.3249 --- Validation for Epoch [17/100], CIoU: 0.37262442509333293
#
# Fold [2/5], Epoch [18/100], CIoU: 0.3437 --- Validation for Epoch [18/100], CIoU: 0.3764463206132253
#
# Fold [2/5], Epoch [19/100], CIoU: 0.3162 --- Validation for Epoch [19/100], CIoU: 0.3647498349348704
#
# Fold [2/5], Epoch [20/100], CIoU: 0.3190 --- Validation for Epoch [20/100], CIoU: 0.347179659207662
# Saving best model for Fold 2 at Epoch 20
#
# Fold [2/5], Epoch [21/100], CIoU: 0.3012 --- Validation for Epoch [21/100], CIoU: 0.3769233504931132
#
# Fold [2/5], Epoch [22/100], CIoU: 0.3031 --- Validation for Epoch [22/100], CIoU: 0.3706291437149048
#
# Fold [2/5], Epoch [23/100], CIoU: 0.3022 --- Validation for Epoch [23/100], CIoU: 0.38943803707758584
#
# Fold [2/5], Epoch [24/100], CIoU: 0.3045 --- Validation for Epoch [24/100], CIoU: 0.3512999216715495
#
# Fold [2/5], Epoch [25/100], CIoU: 0.2723 --- Validation for Epoch [25/100], CIoU: 0.3519108792146047
#
# Fold [2/5], Epoch [26/100], CIoU: 0.2742 --- Validation for Epoch [26/100], CIoU: 0.3159515877564748
# Saving best model for Fold 2 at Epoch 26
#
# Fold [2/5], Epoch [27/100], CIoU: 0.2613 --- Validation for Epoch [27/100], CIoU: 0.33384212156136833
#
# Fold [2/5], Epoch [28/100], CIoU: 0.2564 --- Validation for Epoch [28/100], CIoU: 0.3169115444024404
#
# Fold [2/5], Epoch [29/100], CIoU: 0.2546 --- Validation for Epoch [29/100], CIoU: 0.3278531312942505
#
# Fold [2/5], Epoch [30/100], CIoU: 0.3317 --- Validation for Epoch [30/100], CIoU: 0.4058861235777537
#
# Fold [2/5], Epoch [31/100], CIoU: 0.2888 --- Validation for Epoch [31/100], CIoU: 0.36994440158208214
#
# Fold [2/5], Epoch [32/100], CIoU: 0.2764 --- Validation for Epoch [32/100], CIoU: 0.321338881055514
#
# Fold [2/5], Epoch [33/100], CIoU: 0.2470 --- Validation for Epoch [33/100], CIoU: 0.3294565816720327
#
# Fold [2/5], Epoch [34/100], CIoU: 0.2562 --- Validation for Epoch [34/100], CIoU: 0.357821790377299
#
# Fold [2/5], Epoch [35/100], CIoU: 0.2379 --- Validation for Epoch [35/100], CIoU: 0.3414526144663493
#
# Fold [2/5], Epoch [36/100], CIoU: 0.2381 --- Validation for Epoch [36/100], CIoU: 0.318055655558904
#
# Fold [2/5], Epoch [37/100], CIoU: 0.2360 --- Validation for Epoch [37/100], CIoU: 0.3188478151957194
#
# Fold [2/5], Epoch [38/100], CIoU: 0.2317 --- Validation for Epoch [38/100], CIoU: 0.36814934213956196
#
# Fold [2/5], Epoch [39/100], CIoU: 0.2368 --- Validation for Epoch [39/100], CIoU: 0.30392103592554726
# Saving best model for Fold 2 at Epoch 39
#
# Fold [2/5], Epoch [40/100], CIoU: 0.2278 --- Validation for Epoch [40/100], CIoU: 0.34779115120569865
#
# Fold [2/5], Epoch [41/100], CIoU: 0.2345 --- Validation for Epoch [41/100], CIoU: 0.32464619278907775
#
# Fold [2/5], Epoch [42/100], CIoU: 0.2207 --- Validation for Epoch [42/100], CIoU: 0.3322952608267466
#
# Fold [2/5], Epoch [43/100], CIoU: 0.2097 --- Validation for Epoch [43/100], CIoU: 0.33507998983065285
#
# Fold [2/5], Epoch [44/100], CIoU: 0.2116 --- Validation for Epoch [44/100], CIoU: 0.3326419075330099
#
# Fold [2/5], Epoch [45/100], CIoU: 0.2111 --- Validation for Epoch [45/100], CIoU: 0.3240960876146952
#
# Fold [2/5], Epoch [46/100], CIoU: 0.2067 --- Validation for Epoch [46/100], CIoU: 0.3016568849484126
# Saving best model for Fold 2 at Epoch 46
#
# Fold [2/5], Epoch [47/100], CIoU: 0.1937 --- Validation for Epoch [47/100], CIoU: 0.3223940511544546
#
# Fold [2/5], Epoch [48/100], CIoU: 0.1998 --- Validation for Epoch [48/100], CIoU: 0.3419704000155131
#
# Fold [2/5], Epoch [49/100], CIoU: 0.2036 --- Validation for Epoch [49/100], CIoU: 0.3190165291229884
#
# Fold [2/5], Epoch [50/100], CIoU: 0.1986 --- Validation for Epoch [50/100], CIoU: 0.319249701499939
#
# Fold [2/5], Epoch [51/100], CIoU: 0.2080 --- Validation for Epoch [51/100], CIoU: 0.3285177191098531
#
# Fold [2/5], Epoch [52/100], CIoU: 0.2090 --- Validation for Epoch [52/100], CIoU: 0.33099524180094403
#
# Fold [2/5], Epoch [53/100], CIoU: 0.1973 --- Validation for Epoch [53/100], CIoU: 0.3039359122514725
#
# Fold [2/5], Epoch [54/100], CIoU: 0.1918 --- Validation for Epoch [54/100], CIoU: 0.31326797803243
#
# Fold [2/5], Epoch [55/100], CIoU: 0.1869 --- Validation for Epoch [55/100], CIoU: 0.3210879385471344
#
# Fold [2/5], Epoch [56/100], CIoU: 0.2045 --- Validation for Epoch [56/100], CIoU: 0.3151791493097941
#
# Fold [2/5], Epoch [57/100], CIoU: 0.1810 --- Validation for Epoch [57/100], CIoU: 0.3248383124669393
#
# Fold [2/5], Epoch [58/100], CIoU: 0.1853 --- Validation for Epoch [58/100], CIoU: 0.31937337120374043
#
# Fold [2/5], Epoch [59/100], CIoU: 0.1729 --- Validation for Epoch [59/100], CIoU: 0.3229488531748454
#
# Fold [2/5], Epoch [60/100], CIoU: 0.1803 --- Validation for Epoch [60/100], CIoU: 0.3334205647309621
#
# Fold [2/5], Epoch [61/100], CIoU: 0.1838 --- Validation for Epoch [61/100], CIoU: 0.3070791522661845
#
# Fold [2/5], Epoch [62/100], CIoU: 0.1893 --- Validation for Epoch [62/100], CIoU: 0.32607120275497437
#
# Fold [2/5], Epoch [63/100], CIoU: 0.1762 --- Validation for Epoch [63/100], CIoU: 0.300277179479599
# Saving best model for Fold 2 at Epoch 63
#
# Fold [2/5], Epoch [64/100], CIoU: 0.1787 --- Validation for Epoch [64/100], CIoU: 0.2981489529212316
# Saving best model for Fold 2 at Epoch 64
#
# Fold [2/5], Epoch [65/100], CIoU: 0.1680 --- Validation for Epoch [65/100], CIoU: 0.3251257061958313
#
# Fold [2/5], Epoch [66/100], CIoU: 0.1793 --- Validation for Epoch [66/100], CIoU: 0.31782175501187643
#
# Fold [2/5], Epoch [67/100], CIoU: 0.1736 --- Validation for Epoch [67/100], CIoU: 0.3141684472560883
#
# Fold [2/5], Epoch [68/100], CIoU: 0.1857 --- Validation for Epoch [68/100], CIoU: 0.3174529731273651
#
# Fold [2/5], Epoch [69/100], CIoU: 0.1826 --- Validation for Epoch [69/100], CIoU: 0.314379225174586
#
# Fold [2/5], Epoch [70/100], CIoU: 0.1674 --- Validation for Epoch [70/100], CIoU: 0.30032083789507547
#
# Fold [2/5], Epoch [71/100], CIoU: 0.1671 --- Validation for Epoch [71/100], CIoU: 0.3076628486315409
#
# Fold [2/5], Epoch [72/100], CIoU: 0.1762 --- Validation for Epoch [72/100], CIoU: 0.33761194745699563
#
# Fold [2/5], Epoch [73/100], CIoU: 0.1662 --- Validation for Epoch [73/100], CIoU: 0.31810320218404137
#
# Fold [2/5], Epoch [74/100], CIoU: 0.1821 --- Validation for Epoch [74/100], CIoU: 0.30995373825232186
#
# Fold [2/5], Epoch [75/100], CIoU: 0.1637 --- Validation for Epoch [75/100], CIoU: 0.30834304094314574
#
# Fold [2/5], Epoch [76/100], CIoU: 0.1645 --- Validation for Epoch [76/100], CIoU: 0.3137242158253988
#
# Fold [2/5], Epoch [77/100], CIoU: 0.1595 --- Validation for Epoch [77/100], CIoU: 0.33783701856931053
#
# Fold [2/5], Epoch [78/100], CIoU: 0.1648 --- Validation for Epoch [78/100], CIoU: 0.31231281359990437
#
# Fold [2/5], Epoch [79/100], CIoU: 0.1734 --- Validation for Epoch [79/100], CIoU: 0.32552725275357564
#
# Fold [2/5], Epoch [80/100], CIoU: 0.1580 --- Validation for Epoch [80/100], CIoU: 0.33167261282602944
#
# Fold [2/5], Epoch [81/100], CIoU: 0.1608 --- Validation for Epoch [81/100], CIoU: 0.30789900620778404
#
# Fold [2/5], Epoch [82/100], CIoU: 0.1712 --- Validation for Epoch [82/100], CIoU: 0.3090706487496694
#
# Fold [2/5], Epoch [83/100], CIoU: 0.1695 --- Validation for Epoch [83/100], CIoU: 0.32179511785507203
#
# Fold [2/5], Epoch [84/100], CIoU: 0.1595 --- Validation for Epoch [84/100], CIoU: 0.3141373574733734
#
# Fold [2/5], Epoch [85/100], CIoU: 0.1600 --- Validation for Epoch [85/100], CIoU: 0.3122532824675242
#
# Fold [2/5], Epoch [86/100], CIoU: 0.1629 --- Validation for Epoch [86/100], CIoU: 0.29979891578356427
#
# Fold [2/5], Epoch [87/100], CIoU: 0.1540 --- Validation for Epoch [87/100], CIoU: 0.31105738679567974
#
# Fold [2/5], Epoch [88/100], CIoU: 0.1531 --- Validation for Epoch [88/100], CIoU: 0.34804577827453614
#
# Fold [2/5], Epoch [89/100], CIoU: 0.1689 --- Validation for Epoch [89/100], CIoU: 0.3154297669728597
#
# Fold [2/5], Epoch [90/100], CIoU: 0.1531 --- Validation for Epoch [90/100], CIoU: 0.3121561845143636
#
# Fold [2/5], Epoch [91/100], CIoU: 0.1500 --- Validation for Epoch [91/100], CIoU: 0.31728915174802147
#
# Fold [2/5], Epoch [92/100], CIoU: 0.1594 --- Validation for Epoch [92/100], CIoU: 0.30745049118995665
#
# Fold [2/5], Epoch [93/100], CIoU: 0.1430 --- Validation for Epoch [93/100], CIoU: 0.302524987856547
#
# Fold [2/5], Epoch [94/100], CIoU: 0.1586 --- Validation for Epoch [94/100], CIoU: 0.3190542678038279
#
# Fold [2/5], Epoch [95/100], CIoU: 0.1489 --- Validation for Epoch [95/100], CIoU: 0.3071560243765513
#
# Fold [2/5], Epoch [96/100], CIoU: 0.1464 --- Validation for Epoch [96/100], CIoU: 0.3101485431194305
#
# Fold [2/5], Epoch [97/100], CIoU: 0.1396 --- Validation for Epoch [97/100], CIoU: 0.31002543369929
#
# Fold [2/5], Epoch [98/100], CIoU: 0.1435 --- Validation for Epoch [98/100], CIoU: 0.3170308689276377
#
# Fold [2/5], Epoch [99/100], CIoU: 0.1555 --- Validation for Epoch [99/100], CIoU: 0.3108792503674825
#
# Fold [2/5], Epoch [100/100], CIoU: 0.1439 --- Validation for Epoch [100/100], CIoU: 0.3194247841835022
# Best Validation CIoU for Fold 2: 0.2981
# Fold: 3
# -----------------------------------------------------------------------------------------
# Resetting the model for upcoming training session
#
# Fold [3/5], Epoch [1/100], CIoU: 1.0356 --- Validation for Epoch [1/100], CIoU: 1.024750304222107
# Saving best model for Fold 3 at Epoch 1
#
# Fold [3/5], Epoch [2/100], CIoU: 1.0243 --- Validation for Epoch [2/100], CIoU: 1.0259828646977742
#
# Fold [3/5], Epoch [3/100], CIoU: 1.0168 --- Validation for Epoch [3/100], CIoU: 0.9970787763595581
# Saving best model for Fold 3 at Epoch 3
#
# Fold [3/5], Epoch [4/100], CIoU: 0.9720 --- Validation for Epoch [4/100], CIoU: 0.8914392471313477
# Saving best model for Fold 3 at Epoch 4
#
# Fold [3/5], Epoch [5/100], CIoU: 0.7219 --- Validation for Epoch [5/100], CIoU: 0.6458441297213237
# Saving best model for Fold 3 at Epoch 5
#
# Fold [3/5], Epoch [6/100], CIoU: 0.5559 --- Validation for Epoch [6/100], CIoU: 0.514318835735321
# Saving best model for Fold 3 at Epoch 6
#
# Fold [3/5], Epoch [7/100], CIoU: 0.4775 --- Validation for Epoch [7/100], CIoU: 0.5134382804234823
# Saving best model for Fold 3 at Epoch 7
#
# Fold [3/5], Epoch [8/100], CIoU: 0.5169 --- Validation for Epoch [8/100], CIoU: 0.509281986951828
# Saving best model for Fold 3 at Epoch 8
#
# Fold [3/5], Epoch [9/100], CIoU: 0.4286 --- Validation for Epoch [9/100], CIoU: 0.46787991921106975
# Saving best model for Fold 3 at Epoch 9
#
# Fold [3/5], Epoch [10/100], CIoU: 0.4072 --- Validation for Epoch [10/100], CIoU: 0.47630553841590884
#
# Fold [3/5], Epoch [11/100], CIoU: 0.3928 --- Validation for Epoch [11/100], CIoU: 0.4647905151049296
# Saving best model for Fold 3 at Epoch 11
#
# Fold [3/5], Epoch [12/100], CIoU: 0.3752 --- Validation for Epoch [12/100], CIoU: 0.41980130871136984
# Saving best model for Fold 3 at Epoch 12
#
# Fold [3/5], Epoch [13/100], CIoU: 0.3745 --- Validation for Epoch [13/100], CIoU: 0.3998973627885183
# Saving best model for Fold 3 at Epoch 13
#
# Fold [3/5], Epoch [14/100], CIoU: 0.3708 --- Validation for Epoch [14/100], CIoU: 0.4021907349427541
#
# Fold [3/5], Epoch [15/100], CIoU: 0.3539 --- Validation for Epoch [15/100], CIoU: 0.39282067815462746
# Saving best model for Fold 3 at Epoch 15
#
# Fold [3/5], Epoch [16/100], CIoU: 0.3500 --- Validation for Epoch [16/100], CIoU: 0.42396766344706216
#
# Fold [3/5], Epoch [17/100], CIoU: 0.3541 --- Validation for Epoch [17/100], CIoU: 0.4173671583334605
#
# Fold [3/5], Epoch [18/100], CIoU: 0.3337 --- Validation for Epoch [18/100], CIoU: 0.4152131676673889
#
# Fold [3/5], Epoch [19/100], CIoU: 0.3389 --- Validation for Epoch [19/100], CIoU: 0.3753995537757874
# Saving best model for Fold 3 at Epoch 19
#
# Fold [3/5], Epoch [20/100], CIoU: 0.3242 --- Validation for Epoch [20/100], CIoU: 0.3963380932807922
#
# Fold [3/5], Epoch [21/100], CIoU: 0.3189 --- Validation for Epoch [21/100], CIoU: 0.38846999406814575
#
# Fold [3/5], Epoch [22/100], CIoU: 0.3350 --- Validation for Epoch [22/100], CIoU: 0.48302109638849894
#
# Fold [3/5], Epoch [23/100], CIoU: 0.3400 --- Validation for Epoch [23/100], CIoU: 0.3625142157077789
# Saving best model for Fold 3 at Epoch 23
#
# Fold [3/5], Epoch [24/100], CIoU: 0.3128 --- Validation for Epoch [24/100], CIoU: 0.3802915354569753
#
# Fold [3/5], Epoch [25/100], CIoU: 0.2952 --- Validation for Epoch [25/100], CIoU: 0.38410329023996986
#
# Fold [3/5], Epoch [26/100], CIoU: 0.3115 --- Validation for Epoch [26/100], CIoU: 0.3689805348714193
#
# Fold [3/5], Epoch [27/100], CIoU: 0.2981 --- Validation for Epoch [27/100], CIoU: 0.3601861000061035
# Saving best model for Fold 3 at Epoch 27
#
# Fold [3/5], Epoch [28/100], CIoU: 0.3120 --- Validation for Epoch [28/100], CIoU: 0.3656193157037099
#
# Fold [3/5], Epoch [29/100], CIoU: 0.2996 --- Validation for Epoch [29/100], CIoU: 0.36166386206944784
#
# Fold [3/5], Epoch [30/100], CIoU: 0.2866 --- Validation for Epoch [30/100], CIoU: 0.3539335191249847
# Saving best model for Fold 3 at Epoch 30
#
# Fold [3/5], Epoch [31/100], CIoU: 0.2775 --- Validation for Epoch [31/100], CIoU: 0.3584995607535044
#
# Fold [3/5], Epoch [32/100], CIoU: 0.2802 --- Validation for Epoch [32/100], CIoU: 0.3513479729493459
# Saving best model for Fold 3 at Epoch 32
#
# Fold [3/5], Epoch [33/100], CIoU: 0.2818 --- Validation for Epoch [33/100], CIoU: 0.35919389923413597
#
# Fold [3/5], Epoch [34/100], CIoU: 0.2790 --- Validation for Epoch [34/100], CIoU: 0.34022419253985087
# Saving best model for Fold 3 at Epoch 34
#
# Fold [3/5], Epoch [35/100], CIoU: 0.2616 --- Validation for Epoch [35/100], CIoU: 0.3419531335433324
#
# Fold [3/5], Epoch [36/100], CIoU: 0.2636 --- Validation for Epoch [36/100], CIoU: 0.36941346327463787
#
# Fold [3/5], Epoch [37/100], CIoU: 0.2611 --- Validation for Epoch [37/100], CIoU: 0.34090505838394164
#
# Fold [3/5], Epoch [38/100], CIoU: 0.2630 --- Validation for Epoch [38/100], CIoU: 0.343040136496226
#
# Fold [3/5], Epoch [39/100], CIoU: 0.2570 --- Validation for Epoch [39/100], CIoU: 0.34302953879038495
#
# Fold [3/5], Epoch [40/100], CIoU: 0.2778 --- Validation for Epoch [40/100], CIoU: 0.3522946616013845
#
# Fold [3/5], Epoch [41/100], CIoU: 0.2587 --- Validation for Epoch [41/100], CIoU: 0.3465568393468857
#
# Fold [3/5], Epoch [42/100], CIoU: 0.2558 --- Validation for Epoch [42/100], CIoU: 0.33233350118001304
# Saving best model for Fold 3 at Epoch 42
#
# Fold [3/5], Epoch [43/100], CIoU: 0.2481 --- Validation for Epoch [43/100], CIoU: 0.3453475634256999
#
# Fold [3/5], Epoch [44/100], CIoU: 0.2464 --- Validation for Epoch [44/100], CIoU: 0.3449454168478648
#
# Fold [3/5], Epoch [45/100], CIoU: 0.2496 --- Validation for Epoch [45/100], CIoU: 0.3553012768427531
#
# Fold [3/5], Epoch [46/100], CIoU: 0.2456 --- Validation for Epoch [46/100], CIoU: 0.3392948726812998
#
# Fold [3/5], Epoch [47/100], CIoU: 0.2309 --- Validation for Epoch [47/100], CIoU: 0.3597065051396688
#
# Fold [3/5], Epoch [48/100], CIoU: 0.2375 --- Validation for Epoch [48/100], CIoU: 0.3439319988091787
#
# Fold [3/5], Epoch [49/100], CIoU: 0.2344 --- Validation for Epoch [49/100], CIoU: 0.3452887535095215
#
# Fold [3/5], Epoch [50/100], CIoU: 0.2271 --- Validation for Epoch [50/100], CIoU: 0.3429004311561584
#
# Fold [3/5], Epoch [51/100], CIoU: 0.2402 --- Validation for Epoch [51/100], CIoU: 0.33993091583251955
#
# Fold [3/5], Epoch [52/100], CIoU: 0.2234 --- Validation for Epoch [52/100], CIoU: 0.3490164836247762
#
# Fold [3/5], Epoch [53/100], CIoU: 0.2291 --- Validation for Epoch [53/100], CIoU: 0.34918718139330546
#
# Fold [3/5], Epoch [54/100], CIoU: 0.2163 --- Validation for Epoch [54/100], CIoU: 0.3527437428633372
#
# Fold [3/5], Epoch [55/100], CIoU: 0.2149 --- Validation for Epoch [55/100], CIoU: 0.33234962622324626
#
# Fold [3/5], Epoch [56/100], CIoU: 0.2166 --- Validation for Epoch [56/100], CIoU: 0.31845801174640653
# Saving best model for Fold 3 at Epoch 56
#
# Fold [3/5], Epoch [57/100], CIoU: 0.2182 --- Validation for Epoch [57/100], CIoU: 0.339697257677714
#
# Fold [3/5], Epoch [58/100], CIoU: 0.2133 --- Validation for Epoch [58/100], CIoU: 0.3202882985273997
#
# Fold [3/5], Epoch [59/100], CIoU: 0.2022 --- Validation for Epoch [59/100], CIoU: 0.3083548337221146
# Saving best model for Fold 3 at Epoch 59
#
# Fold [3/5], Epoch [60/100], CIoU: 0.2156 --- Validation for Epoch [60/100], CIoU: 0.32333774169286095
#
# Fold [3/5], Epoch [61/100], CIoU: 0.2048 --- Validation for Epoch [61/100], CIoU: 0.34402847091356914
#
# Fold [3/5], Epoch [62/100], CIoU: 0.2107 --- Validation for Epoch [62/100], CIoU: 0.3245562493801117
#
# Fold [3/5], Epoch [63/100], CIoU: 0.1984 --- Validation for Epoch [63/100], CIoU: 0.3254797438780467
#
# Fold [3/5], Epoch [64/100], CIoU: 0.1975 --- Validation for Epoch [64/100], CIoU: 0.31596321165561675
#
# Fold [3/5], Epoch [65/100], CIoU: 0.1961 --- Validation for Epoch [65/100], CIoU: 0.3283886700868607
#
# Fold [3/5], Epoch [66/100], CIoU: 0.1945 --- Validation for Epoch [66/100], CIoU: 0.31609501242637633
#
# Fold [3/5], Epoch [67/100], CIoU: 0.1949 --- Validation for Epoch [67/100], CIoU: 0.31736202041308087
#
# Fold [3/5], Epoch [68/100], CIoU: 0.1907 --- Validation for Epoch [68/100], CIoU: 0.3115898102521896
#
# Fold [3/5], Epoch [69/100], CIoU: 0.1948 --- Validation for Epoch [69/100], CIoU: 0.3369216521581014
#
# Fold [3/5], Epoch [70/100], CIoU: 0.1999 --- Validation for Epoch [70/100], CIoU: 0.31314513882001244
#
# Fold [3/5], Epoch [71/100], CIoU: 0.1877 --- Validation for Epoch [71/100], CIoU: 0.31527702311674755
#
# Fold [3/5], Epoch [72/100], CIoU: 0.1908 --- Validation for Epoch [72/100], CIoU: 0.3037749320268631
# Saving best model for Fold 3 at Epoch 72
#
# Fold [3/5], Epoch [73/100], CIoU: 0.1895 --- Validation for Epoch [73/100], CIoU: 0.3583354453245799
#
# Fold [3/5], Epoch [74/100], CIoU: 0.2070 --- Validation for Epoch [74/100], CIoU: 0.31325834691524507
#
# Fold [3/5], Epoch [75/100], CIoU: 0.1863 --- Validation for Epoch [75/100], CIoU: 0.3281308869520823
#
# Fold [3/5], Epoch [76/100], CIoU: 0.1752 --- Validation for Epoch [76/100], CIoU: 0.3118370165427526
#
# Fold [3/5], Epoch [77/100], CIoU: 0.1733 --- Validation for Epoch [77/100], CIoU: 0.3222760240236918
#
# Fold [3/5], Epoch [78/100], CIoU: 0.1805 --- Validation for Epoch [78/100], CIoU: 0.3276579121748606
#
# Fold [3/5], Epoch [79/100], CIoU: 0.1750 --- Validation for Epoch [79/100], CIoU: 0.31774964928627014
#
# Fold [3/5], Epoch [80/100], CIoU: 0.1744 --- Validation for Epoch [80/100], CIoU: 0.3279697199662526
#
# Fold [3/5], Epoch [81/100], CIoU: 0.1854 --- Validation for Epoch [81/100], CIoU: 0.3197313557068507
#
# Fold [3/5], Epoch [82/100], CIoU: 0.1762 --- Validation for Epoch [82/100], CIoU: 0.3146761397520701
#
# Fold [3/5], Epoch [83/100], CIoU: 0.1879 --- Validation for Epoch [83/100], CIoU: 0.3105460822582245
#
# Fold [3/5], Epoch [84/100], CIoU: 0.1757 --- Validation for Epoch [84/100], CIoU: 0.3184394697348277
#
# Fold [3/5], Epoch [85/100], CIoU: 0.1766 --- Validation for Epoch [85/100], CIoU: 0.32140989700953165
#
# Fold [3/5], Epoch [86/100], CIoU: 0.1602 --- Validation for Epoch [86/100], CIoU: 0.2942221562067668
# Saving best model for Fold 3 at Epoch 86
#
# Fold [3/5], Epoch [87/100], CIoU: 0.1708 --- Validation for Epoch [87/100], CIoU: 0.3130633940299352
#
# Fold [3/5], Epoch [88/100], CIoU: 0.1634 --- Validation for Epoch [88/100], CIoU: 0.32523715297381084
#
# Fold [3/5], Epoch [89/100], CIoU: 0.1735 --- Validation for Epoch [89/100], CIoU: 0.307306581735611
#
# Fold [3/5], Epoch [90/100], CIoU: 0.1590 --- Validation for Epoch [90/100], CIoU: 0.3128472685813904
#
# Fold [3/5], Epoch [91/100], CIoU: 0.1722 --- Validation for Epoch [91/100], CIoU: 0.31324870586395265
#
# Fold [3/5], Epoch [92/100], CIoU: 0.1711 --- Validation for Epoch [92/100], CIoU: 0.3038646161556244
#
# Fold [3/5], Epoch [93/100], CIoU: 0.1628 --- Validation for Epoch [93/100], CIoU: 0.30747928023338317
#
# Fold [3/5], Epoch [94/100], CIoU: 0.1622 --- Validation for Epoch [94/100], CIoU: 0.3079878250757853
#
# Fold [3/5], Epoch [95/100], CIoU: 0.1579 --- Validation for Epoch [95/100], CIoU: 0.3134074548880259
#
# Fold [3/5], Epoch [96/100], CIoU: 0.1509 --- Validation for Epoch [96/100], CIoU: 0.31627053022384644
#
# Fold [3/5], Epoch [97/100], CIoU: 0.1598 --- Validation for Epoch [97/100], CIoU: 0.3121568997701009
#
# Fold [3/5], Epoch [98/100], CIoU: 0.1558 --- Validation for Epoch [98/100], CIoU: 0.29552775422732036
#
# Fold [3/5], Epoch [99/100], CIoU: 0.1660 --- Validation for Epoch [99/100], CIoU: 0.3183201183875402
#
# Fold [3/5], Epoch [100/100], CIoU: 0.1550 --- Validation for Epoch [100/100], CIoU: 0.33469343384106953
# Best Validation CIoU for Fold 3: 0.2942
# Fold: 4
# -----------------------------------------------------------------------------------------
# Resetting the model for upcoming training session
#
# Fold [4/5], Epoch [1/100], CIoU: 1.0311 --- Validation for Epoch [1/100], CIoU: 1.0238557497660319
# Saving best model for Fold 4 at Epoch 1
#
# Fold [4/5], Epoch [2/100], CIoU: 1.0179 --- Validation for Epoch [2/100], CIoU: 0.9936704874038697
# Saving best model for Fold 4 at Epoch 2
#
# Fold [4/5], Epoch [3/100], CIoU: 0.9273 --- Validation for Epoch [3/100], CIoU: 0.7920174916585286
# Saving best model for Fold 4 at Epoch 3
#
# Fold [4/5], Epoch [4/100], CIoU: 0.6437 --- Validation for Epoch [4/100], CIoU: 0.5234299182891846
# Saving best model for Fold 4 at Epoch 4
#
# Fold [4/5], Epoch [5/100], CIoU: 0.5224 --- Validation for Epoch [5/100], CIoU: 0.48950605392456054
# Saving best model for Fold 4 at Epoch 5
#
# Fold [4/5], Epoch [6/100], CIoU: 0.4506 --- Validation for Epoch [6/100], CIoU: 0.4830159624417623
# Saving best model for Fold 4 at Epoch 6
#
# Fold [4/5], Epoch [7/100], CIoU: 0.4298 --- Validation for Epoch [7/100], CIoU: 0.4501894136269887
# Saving best model for Fold 4 at Epoch 7
#
# Fold [4/5], Epoch [8/100], CIoU: 0.4168 --- Validation for Epoch [8/100], CIoU: 0.3870494723320007
# Saving best model for Fold 4 at Epoch 8
#
# Fold [4/5], Epoch [9/100], CIoU: 0.4045 --- Validation for Epoch [9/100], CIoU: 0.3820285856723785
# Saving best model for Fold 4 at Epoch 9
#
# Fold [4/5], Epoch [10/100], CIoU: 0.3790 --- Validation for Epoch [10/100], CIoU: 0.3825299123922984
#
# Fold [4/5], Epoch [11/100], CIoU: 0.3750 --- Validation for Epoch [11/100], CIoU: 0.41054442326227825
#
# Fold [4/5], Epoch [12/100], CIoU: 0.3602 --- Validation for Epoch [12/100], CIoU: 0.3990458289782206
#
# Fold [4/5], Epoch [13/100], CIoU: 0.3489 --- Validation for Epoch [13/100], CIoU: 0.36517945925394696
# Saving best model for Fold 4 at Epoch 13
#
# Fold [4/5], Epoch [14/100], CIoU: 0.3363 --- Validation for Epoch [14/100], CIoU: 0.35364171067873634
# Saving best model for Fold 4 at Epoch 14
#
# Fold [4/5], Epoch [15/100], CIoU: 0.3493 --- Validation for Epoch [15/100], CIoU: 0.35612168312072756
#
# Fold [4/5], Epoch [16/100], CIoU: 0.3225 --- Validation for Epoch [16/100], CIoU: 0.33302451968193053
# Saving best model for Fold 4 at Epoch 16
#
# Fold [4/5], Epoch [17/100], CIoU: 0.3135 --- Validation for Epoch [17/100], CIoU: 0.3371021330356598
#
# Fold [4/5], Epoch [18/100], CIoU: 0.3204 --- Validation for Epoch [18/100], CIoU: 0.358981317281723
#
# Fold [4/5], Epoch [19/100], CIoU: 0.3273 --- Validation for Epoch [19/100], CIoU: 0.4013976017634074
#
# Fold [4/5], Epoch [20/100], CIoU: 0.3109 --- Validation for Epoch [20/100], CIoU: 0.3493249833583832
#
# Fold [4/5], Epoch [21/100], CIoU: 0.2981 --- Validation for Epoch [21/100], CIoU: 0.33081486225128176
# Saving best model for Fold 4 at Epoch 21
#
# Fold [4/5], Epoch [22/100], CIoU: 0.2955 --- Validation for Epoch [22/100], CIoU: 0.3176282008488973
# Saving best model for Fold 4 at Epoch 22
#
# Fold [4/5], Epoch [23/100], CIoU: 0.2923 --- Validation for Epoch [23/100], CIoU: 0.33423761526743573
#
# Fold [4/5], Epoch [24/100], CIoU: 0.2883 --- Validation for Epoch [24/100], CIoU: 0.36420536041259766
#
# Fold [4/5], Epoch [25/100], CIoU: 0.2899 --- Validation for Epoch [25/100], CIoU: 0.37294414440790813
#
# Fold [4/5], Epoch [26/100], CIoU: 0.2734 --- Validation for Epoch [26/100], CIoU: 0.35024330417315164
#
# Fold [4/5], Epoch [27/100], CIoU: 0.2665 --- Validation for Epoch [27/100], CIoU: 0.317656280597051
#
# Fold [4/5], Epoch [28/100], CIoU: 0.2690 --- Validation for Epoch [28/100], CIoU: 0.32893810868263246
#
# Fold [4/5], Epoch [29/100], CIoU: 0.2529 --- Validation for Epoch [29/100], CIoU: 0.3106845796108246
# Saving best model for Fold 4 at Epoch 29
#
# Fold [4/5], Epoch [30/100], CIoU: 0.2556 --- Validation for Epoch [30/100], CIoU: 0.31192061901092527
#
# Fold [4/5], Epoch [31/100], CIoU: 0.2533 --- Validation for Epoch [31/100], CIoU: 0.3324902554353078
#
# Fold [4/5], Epoch [32/100], CIoU: 0.2481 --- Validation for Epoch [32/100], CIoU: 0.3311977982521057
#
# Fold [4/5], Epoch [33/100], CIoU: 0.2655 --- Validation for Epoch [33/100], CIoU: 0.3481235961119334
#
# Fold [4/5], Epoch [34/100], CIoU: 0.2575 --- Validation for Epoch [34/100], CIoU: 0.31926053762435913
#
# Fold [4/5], Epoch [35/100], CIoU: 0.2359 --- Validation for Epoch [35/100], CIoU: 0.31543593207995096
#
# Fold [4/5], Epoch [36/100], CIoU: 0.2492 --- Validation for Epoch [36/100], CIoU: 0.3140869677066803
#
# Fold [4/5], Epoch [37/100], CIoU: 0.2458 --- Validation for Epoch [37/100], CIoU: 0.3281260887781779
#
# Fold [4/5], Epoch [38/100], CIoU: 0.2331 --- Validation for Epoch [38/100], CIoU: 0.3214884201685588
#
# Fold [4/5], Epoch [39/100], CIoU: 0.2283 --- Validation for Epoch [39/100], CIoU: 0.30346290171146395
# Saving best model for Fold 4 at Epoch 39
#
# Fold [4/5], Epoch [40/100], CIoU: 0.2220 --- Validation for Epoch [40/100], CIoU: 0.3223739445209503
#
# Fold [4/5], Epoch [41/100], CIoU: 0.2364 --- Validation for Epoch [41/100], CIoU: 0.31015548507372537
#
# Fold [4/5], Epoch [42/100], CIoU: 0.2260 --- Validation for Epoch [42/100], CIoU: 0.3075619955857595
#
# Fold [4/5], Epoch [43/100], CIoU: 0.2164 --- Validation for Epoch [43/100], CIoU: 0.3013243436813354
# Saving best model for Fold 4 at Epoch 43
#
# Fold [4/5], Epoch [44/100], CIoU: 0.2168 --- Validation for Epoch [44/100], CIoU: 0.3410778482755025
#
# Fold [4/5], Epoch [45/100], CIoU: 0.2150 --- Validation for Epoch [45/100], CIoU: 0.31191262205441794
#
# Fold [4/5], Epoch [46/100], CIoU: 0.2212 --- Validation for Epoch [46/100], CIoU: 0.32251320282618207
#
# Fold [4/5], Epoch [47/100], CIoU: 0.2004 --- Validation for Epoch [47/100], CIoU: 0.3076249361038208
#
# Fold [4/5], Epoch [48/100], CIoU: 0.2042 --- Validation for Epoch [48/100], CIoU: 0.2970275898774465
# Saving best model for Fold 4 at Epoch 48
#
# Fold [4/5], Epoch [49/100], CIoU: 0.2068 --- Validation for Epoch [49/100], CIoU: 0.3108200530211131
#
# Fold [4/5], Epoch [50/100], CIoU: 0.2159 --- Validation for Epoch [50/100], CIoU: 0.3109268665313721
#
# Fold [4/5], Epoch [51/100], CIoU: 0.2136 --- Validation for Epoch [51/100], CIoU: 0.29423498809337617
# Saving best model for Fold 4 at Epoch 51
#
# Fold [4/5], Epoch [52/100], CIoU: 0.2017 --- Validation for Epoch [52/100], CIoU: 0.3004560152689616
#
# Fold [4/5], Epoch [53/100], CIoU: 0.1941 --- Validation for Epoch [53/100], CIoU: 0.31149459481239317
#
# Fold [4/5], Epoch [54/100], CIoU: 0.1928 --- Validation for Epoch [54/100], CIoU: 0.2874907314777374
# Saving best model for Fold 4 at Epoch 54
#
# Fold [4/5], Epoch [55/100], CIoU: 0.1837 --- Validation for Epoch [55/100], CIoU: 0.30132149855295814
#
# Fold [4/5], Epoch [56/100], CIoU: 0.1951 --- Validation for Epoch [56/100], CIoU: 0.3158409794171651
#
# Fold [4/5], Epoch [57/100], CIoU: 0.1923 --- Validation for Epoch [57/100], CIoU: 0.295372806986173
#
# Fold [4/5], Epoch [58/100], CIoU: 0.1789 --- Validation for Epoch [58/100], CIoU: 0.31163583795229594
#
# Fold [4/5], Epoch [59/100], CIoU: 0.1825 --- Validation for Epoch [59/100], CIoU: 0.3209250251452128
#
# Fold [4/5], Epoch [60/100], CIoU: 0.2026 --- Validation for Epoch [60/100], CIoU: 0.29698279897371926
#
# Fold [4/5], Epoch [61/100], CIoU: 0.1947 --- Validation for Epoch [61/100], CIoU: 0.29303403397401173
#
# Fold [4/5], Epoch [62/100], CIoU: 0.1924 --- Validation for Epoch [62/100], CIoU: 0.3304344137509664
#
# Fold [4/5], Epoch [63/100], CIoU: 0.1877 --- Validation for Epoch [63/100], CIoU: 0.29739003678162895
#
# Fold [4/5], Epoch [64/100], CIoU: 0.1818 --- Validation for Epoch [64/100], CIoU: 0.28863369723161064
#
# Fold [4/5], Epoch [65/100], CIoU: 0.1787 --- Validation for Epoch [65/100], CIoU: 0.30388225317001344
#
# Fold [4/5], Epoch [66/100], CIoU: 0.1790 --- Validation for Epoch [66/100], CIoU: 0.289542019367218
#
# Fold [4/5], Epoch [67/100], CIoU: 0.1709 --- Validation for Epoch [67/100], CIoU: 0.29498714009920757
#
# Fold [4/5], Epoch [68/100], CIoU: 0.1738 --- Validation for Epoch [68/100], CIoU: 0.2997004638115565
#
# Fold [4/5], Epoch [69/100], CIoU: 0.1738 --- Validation for Epoch [69/100], CIoU: 0.2974518060684204
#
# Fold [4/5], Epoch [70/100], CIoU: 0.1624 --- Validation for Epoch [70/100], CIoU: 0.3061446984608968
#
# Fold [4/5], Epoch [71/100], CIoU: 0.1680 --- Validation for Epoch [71/100], CIoU: 0.299465940395991
#
# Fold [4/5], Epoch [72/100], CIoU: 0.1717 --- Validation for Epoch [72/100], CIoU: 0.31064355969429014
#
# Fold [4/5], Epoch [73/100], CIoU: 0.1722 --- Validation for Epoch [73/100], CIoU: 0.3336236774921417
#
# Fold [4/5], Epoch [74/100], CIoU: 0.1680 --- Validation for Epoch [74/100], CIoU: 0.29560739994049073
#
# Fold [4/5], Epoch [75/100], CIoU: 0.1708 --- Validation for Epoch [75/100], CIoU: 0.29672111868858336
#
# Fold [4/5], Epoch [76/100], CIoU: 0.1699 --- Validation for Epoch [76/100], CIoU: 0.28981553912162783
#
# Fold [4/5], Epoch [77/100], CIoU: 0.1634 --- Validation for Epoch [77/100], CIoU: 0.30299214522043866
#
# Fold [4/5], Epoch [78/100], CIoU: 0.1674 --- Validation for Epoch [78/100], CIoU: 0.29096203049023944
#
# Fold [4/5], Epoch [79/100], CIoU: 0.1593 --- Validation for Epoch [79/100], CIoU: 0.28996159732341764
#
# Fold [4/5], Epoch [80/100], CIoU: 0.1613 --- Validation for Epoch [80/100], CIoU: 0.29889339009920757
#
# Fold [4/5], Epoch [81/100], CIoU: 0.1808 --- Validation for Epoch [81/100], CIoU: 0.30639164050420126
#
# Fold [4/5], Epoch [82/100], CIoU: 0.1853 --- Validation for Epoch [82/100], CIoU: 0.29589188992977145
#
# Fold [4/5], Epoch [83/100], CIoU: 0.1588 --- Validation for Epoch [83/100], CIoU: 0.2929885884126027
#
# Fold [4/5], Epoch [84/100], CIoU: 0.1591 --- Validation for Epoch [84/100], CIoU: 0.2917117257912954
#
# Fold [4/5], Epoch [85/100], CIoU: 0.1753 --- Validation for Epoch [85/100], CIoU: 0.3291561782360077
#
# Fold [4/5], Epoch [86/100], CIoU: 0.1663 --- Validation for Epoch [86/100], CIoU: 0.3155383586883545
#
# Fold [4/5], Epoch [87/100], CIoU: 0.1588 --- Validation for Epoch [87/100], CIoU: 0.3056325376033783
#
# Fold [4/5], Epoch [88/100], CIoU: 0.1592 --- Validation for Epoch [88/100], CIoU: 0.29593885044256846
#
# Fold [4/5], Epoch [89/100], CIoU: 0.1590 --- Validation for Epoch [89/100], CIoU: 0.2955628971258799
#
# Fold [4/5], Epoch [90/100], CIoU: 0.1544 --- Validation for Epoch [90/100], CIoU: 0.296420164903005
#
# Fold [4/5], Epoch [91/100], CIoU: 0.1517 --- Validation for Epoch [91/100], CIoU: 0.29062999884287516
#
# Fold [4/5], Epoch [92/100], CIoU: 0.1540 --- Validation for Epoch [92/100], CIoU: 0.2829626232385635
# Saving best model for Fold 4 at Epoch 92
#
# Fold [4/5], Epoch [93/100], CIoU: 0.1575 --- Validation for Epoch [93/100], CIoU: 0.29664016763369244
#
# Fold [4/5], Epoch [94/100], CIoU: 0.1672 --- Validation for Epoch [94/100], CIoU: 0.2906535545984904
#
# Fold [4/5], Epoch [95/100], CIoU: 0.1562 --- Validation for Epoch [95/100], CIoU: 0.31959790786107384
#
# Fold [4/5], Epoch [96/100], CIoU: 0.1529 --- Validation for Epoch [96/100], CIoU: 0.29065301915009817
#
# Fold [4/5], Epoch [97/100], CIoU: 0.1396 --- Validation for Epoch [97/100], CIoU: 0.28785013059775033
#
# Fold [4/5], Epoch [98/100], CIoU: 0.1465 --- Validation for Epoch [98/100], CIoU: 0.29778715372085574
#
# Fold [4/5], Epoch [99/100], CIoU: 0.1556 --- Validation for Epoch [99/100], CIoU: 0.30008868674437206
#
# Fold [4/5], Epoch [100/100], CIoU: 0.1434 --- Validation for Epoch [100/100], CIoU: 0.3012055983146032
# Best Validation CIoU for Fold 4: 0.2830
# Fold: 5
# -----------------------------------------------------------------------------------------
# Resetting the model for upcoming training session
#
# Fold [5/5], Epoch [1/100], CIoU: 1.0338 --- Validation for Epoch [1/100], CIoU: 1.02373259862264
# Saving best model for Fold 5 at Epoch 1
#
# Fold [5/5], Epoch [2/100], CIoU: 1.0226 --- Validation for Epoch [2/100], CIoU: 1.0189027547836305
# Saving best model for Fold 5 at Epoch 2
#
# Fold [5/5], Epoch [3/100], CIoU: 0.9650 --- Validation for Epoch [3/100], CIoU: 0.9083491047223409
# Saving best model for Fold 5 at Epoch 3
#
# Fold [5/5], Epoch [4/100], CIoU: 0.8047 --- Validation for Epoch [4/100], CIoU: 0.5948054114977519
# Saving best model for Fold 5 at Epoch 4
#
# Fold [5/5], Epoch [5/100], CIoU: 0.5815 --- Validation for Epoch [5/100], CIoU: 0.600409185886383
#
# Fold [5/5], Epoch [6/100], CIoU: 0.4996 --- Validation for Epoch [6/100], CIoU: 0.49459030032157897
# Saving best model for Fold 5 at Epoch 6
#
# Fold [5/5], Epoch [7/100], CIoU: 0.4407 --- Validation for Epoch [7/100], CIoU: 0.42656731605529785
# Saving best model for Fold 5 at Epoch 7
#
# Fold [5/5], Epoch [8/100], CIoU: 0.4202 --- Validation for Epoch [8/100], CIoU: 0.4129453837871552
# Saving best model for Fold 5 at Epoch 8
#
# Fold [5/5], Epoch [9/100], CIoU: 0.4006 --- Validation for Epoch [9/100], CIoU: 0.46061166326204933
#
# Fold [5/5], Epoch [10/100], CIoU: 0.3874 --- Validation for Epoch [10/100], CIoU: 0.45425947308540343
#
# Fold [5/5], Epoch [11/100], CIoU: 0.3829 --- Validation for Epoch [11/100], CIoU: 0.4077783524990082
# Saving best model for Fold 5 at Epoch 11
#
# Fold [5/5], Epoch [12/100], CIoU: 0.3570 --- Validation for Epoch [12/100], CIoU: 0.382032984495163
# Saving best model for Fold 5 at Epoch 12
#
# Fold [5/5], Epoch [13/100], CIoU: 0.3529 --- Validation for Epoch [13/100], CIoU: 0.3584402859210968
# Saving best model for Fold 5 at Epoch 13
#
# Fold [5/5], Epoch [14/100], CIoU: 0.3487 --- Validation for Epoch [14/100], CIoU: 0.38310579061508176
#
# Fold [5/5], Epoch [15/100], CIoU: 0.3423 --- Validation for Epoch [15/100], CIoU: 0.39803365965684256
#
# Fold [5/5], Epoch [16/100], CIoU: 0.3234 --- Validation for Epoch [16/100], CIoU: 0.3788549184799194
#
# Fold [5/5], Epoch [17/100], CIoU: 0.3269 --- Validation for Epoch [17/100], CIoU: 0.3850402613480886
#
# Fold [5/5], Epoch [18/100], CIoU: 0.3296 --- Validation for Epoch [18/100], CIoU: 0.40363884965578717
#
# Fold [5/5], Epoch [19/100], CIoU: 0.3304 --- Validation for Epoch [19/100], CIoU: 0.3729298611481984
#
# Fold [5/5], Epoch [20/100], CIoU: 0.2987 --- Validation for Epoch [20/100], CIoU: 0.3887327869733175
#
# Fold [5/5], Epoch [21/100], CIoU: 0.3083 --- Validation for Epoch [21/100], CIoU: 0.3666177133719126
#
# Fold [5/5], Epoch [22/100], CIoU: 0.2954 --- Validation for Epoch [22/100], CIoU: 0.36451963980992635
#
# Fold [5/5], Epoch [23/100], CIoU: 0.2831 --- Validation for Epoch [23/100], CIoU: 0.34173163374265036
# Saving best model for Fold 5 at Epoch 23
#
# Fold [5/5], Epoch [24/100], CIoU: 0.2793 --- Validation for Epoch [24/100], CIoU: 0.3477481265862783
#
# Fold [5/5], Epoch [25/100], CIoU: 0.2811 --- Validation for Epoch [25/100], CIoU: 0.36721530159314475
#
# Fold [5/5], Epoch [26/100], CIoU: 0.2629 --- Validation for Epoch [26/100], CIoU: 0.33043921589851377
# Saving best model for Fold 5 at Epoch 26
#
# Fold [5/5], Epoch [27/100], CIoU: 0.2678 --- Validation for Epoch [27/100], CIoU: 0.4210686147212982
#
# Fold [5/5], Epoch [28/100], CIoU: 0.2621 --- Validation for Epoch [28/100], CIoU: 0.3411755750576655
#
# Fold [5/5], Epoch [29/100], CIoU: 0.2663 --- Validation for Epoch [29/100], CIoU: 0.3282625595728556
# Saving best model for Fold 5 at Epoch 29
#
# Fold [5/5], Epoch [30/100], CIoU: 0.2537 --- Validation for Epoch [30/100], CIoU: 0.34032802780469257
#
# Fold [5/5], Epoch [31/100], CIoU: 0.2462 --- Validation for Epoch [31/100], CIoU: 0.38596357504526774
#
# Fold [5/5], Epoch [32/100], CIoU: 0.2592 --- Validation for Epoch [32/100], CIoU: 0.3483305474122365
#
# Fold [5/5], Epoch [33/100], CIoU: 0.2667 --- Validation for Epoch [33/100], CIoU: 0.36654807527860006
#
# Fold [5/5], Epoch [34/100], CIoU: 0.2441 --- Validation for Epoch [34/100], CIoU: 0.33595306078592935
#
# Fold [5/5], Epoch [35/100], CIoU: 0.2430 --- Validation for Epoch [35/100], CIoU: 0.3682297170162201
#
# Fold [5/5], Epoch [36/100], CIoU: 0.2530 --- Validation for Epoch [36/100], CIoU: 0.31186227897802987
# Saving best model for Fold 5 at Epoch 36
#
# Fold [5/5], Epoch [37/100], CIoU: 0.2217 --- Validation for Epoch [37/100], CIoU: 0.32866867184638976
#
# Fold [5/5], Epoch [38/100], CIoU: 0.2300 --- Validation for Epoch [38/100], CIoU: 0.31655881404876707
#
# Fold [5/5], Epoch [39/100], CIoU: 0.2184 --- Validation for Epoch [39/100], CIoU: 0.3275743762652079
#
# Fold [5/5], Epoch [40/100], CIoU: 0.2181 --- Validation for Epoch [40/100], CIoU: 0.3379335602124532
#
# Fold [5/5], Epoch [41/100], CIoU: 0.2307 --- Validation for Epoch [41/100], CIoU: 0.3127714216709137
#
# Fold [5/5], Epoch [42/100], CIoU: 0.2240 --- Validation for Epoch [42/100], CIoU: 0.33780125180880227
#
# Fold [5/5], Epoch [43/100], CIoU: 0.2090 --- Validation for Epoch [43/100], CIoU: 0.3087842732667923
# Saving best model for Fold 5 at Epoch 43
#
# Fold [5/5], Epoch [44/100], CIoU: 0.1990 --- Validation for Epoch [44/100], CIoU: 0.2980918357769648
# Saving best model for Fold 5 at Epoch 44
#
# Fold [5/5], Epoch [45/100], CIoU: 0.2048 --- Validation for Epoch [45/100], CIoU: 0.3170352677504222
#
# Fold [5/5], Epoch [46/100], CIoU: 0.2040 --- Validation for Epoch [46/100], CIoU: 0.330581663052241
#
# Fold [5/5], Epoch [47/100], CIoU: 0.2087 --- Validation for Epoch [47/100], CIoU: 0.33221423625946045
#
# Fold [5/5], Epoch [48/100], CIoU: 0.2115 --- Validation for Epoch [48/100], CIoU: 0.3402402420838674
#
# Fold [5/5], Epoch [49/100], CIoU: 0.2104 --- Validation for Epoch [49/100], CIoU: 0.32880515257517495
#
# Fold [5/5], Epoch [50/100], CIoU: 0.2069 --- Validation for Epoch [50/100], CIoU: 0.33026121656099955
#
# Fold [5/5], Epoch [51/100], CIoU: 0.2019 --- Validation for Epoch [51/100], CIoU: 0.3181563834349314
#
# Fold [5/5], Epoch [52/100], CIoU: 0.2349 --- Validation for Epoch [52/100], CIoU: 0.4170693198839823
#
# Fold [5/5], Epoch [53/100], CIoU: 0.2766 --- Validation for Epoch [53/100], CIoU: 0.3277470012505849
#
# Fold [5/5], Epoch [54/100], CIoU: 0.2098 --- Validation for Epoch [54/100], CIoU: 0.32017510930697124
#
# Fold [5/5], Epoch [55/100], CIoU: 0.2080 --- Validation for Epoch [55/100], CIoU: 0.3534107506275177
#
# Fold [5/5], Epoch [56/100], CIoU: 0.1863 --- Validation for Epoch [56/100], CIoU: 0.315474804242452
#
# Fold [5/5], Epoch [57/100], CIoU: 0.1974 --- Validation for Epoch [57/100], CIoU: 0.3300465404987335
#
# Fold [5/5], Epoch [58/100], CIoU: 0.1998 --- Validation for Epoch [58/100], CIoU: 0.3165946404139201
#
# Fold [5/5], Epoch [59/100], CIoU: 0.1918 --- Validation for Epoch [59/100], CIoU: 0.33396268089612324
#
# Fold [5/5], Epoch [60/100], CIoU: 0.1883 --- Validation for Epoch [60/100], CIoU: 0.30330246488253276
#
# Fold [5/5], Epoch [61/100], CIoU: 0.1771 --- Validation for Epoch [61/100], CIoU: 0.31435320576032005
#
# Fold [5/5], Epoch [62/100], CIoU: 0.1806 --- Validation for Epoch [62/100], CIoU: 0.32482775549093884
#
# Fold [5/5], Epoch [63/100], CIoU: 0.1766 --- Validation for Epoch [63/100], CIoU: 0.29934160808722177
#
# Fold [5/5], Epoch [64/100], CIoU: 0.1812 --- Validation for Epoch [64/100], CIoU: 0.32220080693562825
#
# Fold [5/5], Epoch [65/100], CIoU: 0.1855 --- Validation for Epoch [65/100], CIoU: 0.3223125159740448
#
# Fold [5/5], Epoch [66/100], CIoU: 0.1845 --- Validation for Epoch [66/100], CIoU: 0.3266078134377797
#
# Fold [5/5], Epoch [67/100], CIoU: 0.1838 --- Validation for Epoch [67/100], CIoU: 0.3269387662410736
#
# Fold [5/5], Epoch [68/100], CIoU: 0.1723 --- Validation for Epoch [68/100], CIoU: 0.3202961544195811
#
# Fold [5/5], Epoch [69/100], CIoU: 0.1701 --- Validation for Epoch [69/100], CIoU: 0.3255395978689194
#
# Fold [5/5], Epoch [70/100], CIoU: 0.1774 --- Validation for Epoch [70/100], CIoU: 0.3173522690931956
#
# Fold [5/5], Epoch [71/100], CIoU: 0.1785 --- Validation for Epoch [71/100], CIoU: 0.31132275263468423
#
# Fold [5/5], Epoch [72/100], CIoU: 0.1734 --- Validation for Epoch [72/100], CIoU: 0.31722626884778343
#
# Fold [5/5], Epoch [73/100], CIoU: 0.1603 --- Validation for Epoch [73/100], CIoU: 0.30740268230438234
#
# Fold [5/5], Epoch [74/100], CIoU: 0.1547 --- Validation for Epoch [74/100], CIoU: 0.3139923453330994
#
# Fold [5/5], Epoch [75/100], CIoU: 0.1642 --- Validation for Epoch [75/100], CIoU: 0.32301834026972454
#
# Fold [5/5], Epoch [76/100], CIoU: 0.1680 --- Validation for Epoch [76/100], CIoU: 0.30371194978555044
#
# Fold [5/5], Epoch [77/100], CIoU: 0.1815 --- Validation for Epoch [77/100], CIoU: 0.3115038375059764
#
# Fold [5/5], Epoch [78/100], CIoU: 0.1590 --- Validation for Epoch [78/100], CIoU: 0.3092877358198166
#
# Fold [5/5], Epoch [79/100], CIoU: 0.1709 --- Validation for Epoch [79/100], CIoU: 0.34198207954565685
#
# Fold [5/5], Epoch [80/100], CIoU: 0.1591 --- Validation for Epoch [80/100], CIoU: 0.3154690325260162
#
# Fold [5/5], Epoch [81/100], CIoU: 0.1612 --- Validation for Epoch [81/100], CIoU: 0.31285947958628335
#
# Fold [5/5], Epoch [82/100], CIoU: 0.1598 --- Validation for Epoch [82/100], CIoU: 0.3054839273293813
#
# Fold [5/5], Epoch [83/100], CIoU: 0.1716 --- Validation for Epoch [83/100], CIoU: 0.3345940371354421
#
# Fold [5/5], Epoch [84/100], CIoU: 0.1707 --- Validation for Epoch [84/100], CIoU: 0.3045514812072118
#
# Fold [5/5], Epoch [85/100], CIoU: 0.1612 --- Validation for Epoch [85/100], CIoU: 0.3240208903948466
#
# Fold [5/5], Epoch [86/100], CIoU: 0.1534 --- Validation for Epoch [86/100], CIoU: 0.31689226826032
#
# Fold [5/5], Epoch [87/100], CIoU: 0.1611 --- Validation for Epoch [87/100], CIoU: 0.3109592984120051
#
# Fold [5/5], Epoch [88/100], CIoU: 0.1574 --- Validation for Epoch [88/100], CIoU: 0.30709822475910187
#
# Fold [5/5], Epoch [89/100], CIoU: 0.1692 --- Validation for Epoch [89/100], CIoU: 0.3167951097091039
#
# Fold [5/5], Epoch [90/100], CIoU: 0.1595 --- Validation for Epoch [90/100], CIoU: 0.3111365775267283
#
# Fold [5/5], Epoch [91/100], CIoU: 0.1510 --- Validation for Epoch [91/100], CIoU: 0.31519542932510375
#
# Fold [5/5], Epoch [92/100], CIoU: 0.1623 --- Validation for Epoch [92/100], CIoU: 0.3054539958635966
#
# Fold [5/5], Epoch [93/100], CIoU: 0.1483 --- Validation for Epoch [93/100], CIoU: 0.31123167475064595
#
# Fold [5/5], Epoch [94/100], CIoU: 0.1535 --- Validation for Epoch [94/100], CIoU: 0.3069078832864761
#
# Fold [5/5], Epoch [95/100], CIoU: 0.1535 --- Validation for Epoch [95/100], CIoU: 0.3292991161346436
#
# Fold [5/5], Epoch [96/100], CIoU: 0.1454 --- Validation for Epoch [96/100], CIoU: 0.30133250951766966
#
# Fold [5/5], Epoch [97/100], CIoU: 0.1469 --- Validation for Epoch [97/100], CIoU: 0.3100758651892344
#
# Fold [5/5], Epoch [98/100], CIoU: 0.1586 --- Validation for Epoch [98/100], CIoU: 0.3044584482908249
#
# Fold [5/5], Epoch [99/100], CIoU: 0.1534 --- Validation for Epoch [99/100], CIoU: 0.3142210006713867
#
# Fold [5/5], Epoch [100/100], CIoU: 0.1434 --- Validation for Epoch [100/100], CIoU: 0.30109356294075645
# Best Validation CIoU for Fold 5: 0.2981
#
# K-Fold Cross-Validation Results:
# Fold	Best Validation CIoU Loss
# 1	0.2848
# 2	0.2981
# 3	0.2942
# 4	0.2830
# 5	0.2981
#
# Average Validation CIoU Loss Across All Folds: 0.2916
