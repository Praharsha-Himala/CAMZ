# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"D:\Praharsha\code\CAMZ\models\Semi_supervised_training_history\1.0-CNN\1.0-CNN\pseudo_labels_semi0.csv")
data = data.drop(['filename'], axis=1)
data.head()
# Out:
#                                         bounding_box  ciou_loss
# 0  [[0.2835732102394104, 0.6457277536392212, 0.12...   0.845291
# 1  [[0.2581249177455902, 0.6843334436416626, 0.13...   1.136877
# 2  [[0.28372204303741455, 0.644884467124939, 0.16...   1.309440
# 3  [[0.2997095584869385, 0.6928921341896057, 0.12...   1.356567
# 4  [[0.24029776453971863, 0.7033430933952332, 0.1...   1.310640

# %%
plt.hist(data['ciou_loss'])
plt.show()

# %%
for round in range(4):
    data = pd.read_csv(rf"D:\Praharsha\code\CAMZ\models\Semi_supervised_training_history\1.0-CNN\1.0-CNN\pseudo_labels_semi{round}.csv")
    plt.hist(data['ciou_loss'])
    plt.grid()
    plt.show()
